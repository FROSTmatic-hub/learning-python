# %% [markdown]
# # ==========================================
# # GIVEN DATA INPUTS
# # ==========================================
#
# # 1. Raw Telemetry Log String
# telemetry_log = "  LOG_ID:9876543210_KEY:X9A8B7C6D5_METRIC:0048.50_QTY:004  "
#
# # 2. Multidimensional Matrix (Sensor Readings)
# sensor_matrix = [
#     [10, 20, 30],
#     [40, 50, 60],
#     [70, 80, 90]
# ]
#
# # 3. Access Permission Sets
# network_permissions = ["read", "write", "execute", "firewall", "write", "audit"]
# cloud_permissions = ["write", "deploy", "firewall", "backup", "deploy"]
# ir_permissions = ["monitor", "isolate", "dump_memory", "read"]
#
# # 4. Incoming User Session Log (Tuples: user_id, session_hours, role)
# session_log = [
#     ("usr_101", 2.5, "admin"),
#     ("usr_102", 4.0, "member"),
#     ("usr_101", 1.5, "admin"),
#     ("usr_103", 3.0, "member"),
#     ("usr_102", 1.0, "member")
# ]
#
# # ==========================================
# # TASK 1: STRING PARSING & DATA CLEANSING
# # ==========================================
#
# # Remove all whitespace
# clean_log = telemetry_log.replace(" ", "")
#
# # Extract 10-character key value (indices 21 to 31) and reverse it
# key_code = clean_log[21:31][::-1]
#
# # Extract numeric values using negative index slicing
# metric_val = float(clean_log[-18:-8])
# qty_val = int(clean_log[-3:])
#
# # Calculate subtotal and dynamic discount
# subtotal = metric_val * qty_val
# final_metric_total = subtotal - (subtotal % 10)
#
# # ==========================================
# # TASK 2: MATRIX INDEXING & EXPRESSION EVALUATION
# # ==========================================
#
# center_element = sensor_matrix[1][1]
# bottom_right_element = sensor_matrix[2][2]
#
# # Compute matrix_score
# matrix_score = center_element + (bottom_right_element * 2**2 // 4) - abs(-15)
#
# # ==========================================
# # TASK 3: SECURITY SET OPERATIONS & AUDITING
# # ==========================================
#
# net_set = set(network_permissions)
# cloud_set = set(cloud_permissions)
# ir_set = set(ir_permissions)
#
# net_set.add("sudo")
#
# net_backup = net_set.copy()
# net_backup.clear()
#
# shared_access = net_set.intersection(cloud_set)
# exclusive_net = net_set.difference(cloud_set)
#
# # Remove all permissions present in ir_set from net_set in-place
# net_set.difference_update(ir_set)
#
# is_separated = cloud_set.isdisjoint(ir_set)
# is_super = net_set.issuperset({"write", "sudo"})
#
# # ==========================================
# # TASK 4: MANUAL LOG AGGREGATION (NO LOOPS)
# # ==========================================
#
# user_summary = {}
#
# # Unpack tuple 0
# u_id, hours, role = session_log[0]
# user_summary[u_id] = {
#     "hours": user_summary.get(u_id, {}).get("hours", 0.0) + hours,
#     "role": role
# }
#
# # Unpack tuple 1
# u_id, hours, role = session_log[1]
# user_summary[u_id] = {
#     "hours": user_summary.get(u_id, {}).get("hours", 0.0) + hours,
#     "role": role
# }
#
# # Unpack tuple 2
# u_id, hours, role = session_log[2]
# user_summary[u_id] = {
#     "hours": user_summary.get(u_id, {}).get("hours", 0.0) + hours,
#     "role": role
# }
#
# # Unpack tuple 3
# u_id, hours, role = session_log[3]
# user_summary[u_id] = {
#     "hours": user_summary.get(u_id, {}).get("hours", 0.0) + hours,
#     "role": role
# }
#
# # Unpack tuple 4
# u_id, hours, role = session_log[4]
# user_summary[u_id] = {
#     "hours": user_summary.get(u_id, {}).get("hours", 0.0) + hours,
#     "role": role
# }
#
# # Safely extract usr_101's total calculated hours
# usr101_hours = user_summary.get("usr_101", {}).get("hours", 0.0)
#
# # ==========================================
# # TASK 5: AUDIT REPORT GENERATION
# # ==========================================
#
# final_report = f"""=== DATA ENGINE AUDIT REPORT===
#  Log Metrics:
#  - Reversed Key: {key_code}
#  - Final Metric Total: {final_metric_total}
#  - Matrix Precedence Score: {matrix_score}
#  Security Audit:
#  - Shared Access: {shared_access}
#  - Exclusive Network Permissions: {exclusive_net}
#  - Disjoint Operators: {is_separated} | Super Admin: {is_super}
#  User Summary:
#  - User 101 Total Hours: {usr101_hours}"""
#
# print(final_report)

# %%
# --- RAW DATA INPUTS ---

# 1. Raw Telemetry Log String
telemetry_log = "  LOG_ID:9876543210_KEY:X9A8B7C6D5_METRIC:0048.50_QTY:004  "

# 2. Multidimensional Matrix (Sensor Readings)
sensor_matrix = [
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
]

# 3. Access Permission Sets
network_permissions = ["read", "write", "execute", "firewall", "write", "audit"]
cloud_permissions = ["write", "deploy", "firewall", "backup", "deploy"]
ir_permissions = ["monitor", "isolate", "dump_memory", "read"]

# 4. Incoming User Session Log (Tuples: user_id, session_hours, role)
session_log = [
    ("usr_101", 2.5, "admin"),
    ("usr_102", 4.0, "member"),
    ("usr_101", 1.5, "admin"),
    ("usr_103", 3.0, "member"),
    ("usr_102", 1.0, "member")
]
# Task 1
clean_log = telemetry_log.replace(" ", "")
# print(clean_log) #LOG_ID:9876543210_KEY:X9A8B7C6D5_METRIC:0048.50_QTY:004

# 2
key_code = clean_log[21:32]
key_code = key_code[::-1]
# print(key_code) _5D6C7B8A9X:YEK

metric_str = clean_log[-15:-8]
# print(metric_str)    0048.50
metric_val = float(metric_str)

qty_str = clean_log[-3:]
qty_val = int(qty_str)

# 3
subtotal = metric_val * qty_val

# 4
discount = subtotal % 10 
subtotal -= discount
final_metric_total = subtotal
# print(final_metric_total)

# Task 2
# sensor_matrix = [
#     [10, 20, 30],
#     [40, 50, 60],
#     [70, 80, 90]
# ]
center_element = sensor_matrix[1][1]
# print(center_element)  50
bottom_right_element = sensor_matrix[2][2]
# print(bottom_right_element)     90

matrix_score = center_element + bottom_right_element * 2 ** 2//4 - abs(-15)

# Task 3
# network_permissions = ["read", "write", "execute", "firewall", "write", "audit"]
# cloud_permissions = ["write", "deploy", "firewall", "backup", "deploy"]
# ir_permissions = ["monitor", "isolate", "dump_memory", "read"]

net_set = set(network_permissions)
cloud_set = set(cloud_permissions)
ir_set = set(ir_permissions)

net_set.add("sudo")

net_backup = net_set.copy()
net_backup.clear()

shared_access = net_set.intersection(cloud_set)
exclusive_net = net_set.difference(cloud_set)

net_set.difference_update(ir_set)

is_separated = cloud_set.isdisjoint(ir_set)
is_super = net_set.issuperset({"write", "sudo"})

# Task 4
#  Incoming User Session Log (Tuples: user_id, session_hours, role)
# session_log = [
#     ("usr_101", 2.5, "admin"),
#     ("usr_102", 4.0, "member"),
#     ("usr_101", 1.5, "admin"),
#     ("usr_103", 3.0, "member"),
#     ("usr_102", 1.0, "member")
# ]
user_summary = {}

# session 1
user_id, hours, role = session_log[0]  #("usr_101", 2.5, "admin")

user_summary[user_id] = {
    "hours" : hours,  #2.5
    "role" : role
}

# session 2
user_id, hours, role = session_log[1]
user_summary[user_id] = {
    "hours" : hours,
    "role" : role
}
# session 3 
user_id, hours, role = session_log[2]   #("usr_101", 1.5, "admin")
user_summary[user_id]["hours"] += hours
# print(user_summary)

# session 4
user_id, hours, role = session_log[3]
user_summary[user_id]= {
    "hours" : hours,
    "role" : role
}
# print(user_summary)

#session 5   #("usr_102", 1.0, "member")
user_id, hours, role = session_log[4]
user_summary[user_id]["hours"] += hours
# print(user_summary)
usr_101_info = user_summary.get("usr_101")
print(usr_101_info)
usr101_hours = usr_101_info.get("hours")
print(usr101_hours)

# Task 5
final_report = f"=== DATA ENGINE AUDIT REPORT===\n Log Metrics:\n - Reversed Key: {key_code}\n -Final Metric Total: {final_metric_total}\n -Matrix Precedence Score: {matrix_score}\n Security Audit:\n -Shared Access: {shared_access}\n - Exclusive Network Permissions: {exclusive_net}\n - Disjoint Operators: {is_separated} | Super Admin: {is_super}\n User Summary:\n - User 101 Total Hours: {usr101_hours}"
print(final_report)
# Out:
# {'hours': 4.0, 'role': 'admin'}
# 4.0
# === DATA ENGINE AUDIT REPORT===
#  Log Metrics:
#  - Reversed Key: _5D6C7B8A9X:YEK
#  -Final Metric Total: 190.0
#  -Matrix Precedence Score: 125
#  Security Audit:
#  -Shared Access: {'write', 'firewall'}
#  - Exclusive Network Permissions: {'audit', 'execute', 'read', 'sudo'}
#  - Disjoint Operators: True | Super Admin: True
#  User Summary:
#  - User 101 Total Hours: 4.0
